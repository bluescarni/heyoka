# %%
# core stuff
import numpy as np
import pickle as pk
from copy import deepcopy

# plotting stuff
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
# %matplotlib notebook

# Ensure that changes in imported module (gravann most importantly) are autoreloaded
# %load_ext autoreload
# %autoreload 2

# %%
# Load all data (produced using apophis.cpp benchmark)
with open("data/apophis_err.pk", "rb") as file:
   err_apophis = pk.load(file)
err_apophis[:,0] = err_apophis[:,0] / 60 / 60 / 24 / 365.25

# %%
plt.figure(figsize=(4.5,3))
plt.semilogy(err_apophis[:,0], err_apophis[:,1], 'C7.', label="Position error (m)")
plt.semilogy(err_apophis[:,0], err_apophis[:,2], 'k.', label="Velocity error (m/s)")
plt.xlabel("Time to close approach (years)")
plt.ylabel("Error (see legend)")
plt.legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="450">

# %%
plt.savefig("apophis.png", dpi = 600)
