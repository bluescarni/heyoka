# %% [markdown]
# # Conversion of VSOP2013 data files to C++

# %%
# Template for the header file output.
HPP_FILE_TMPLT = r"""#ifndef HEYOKA_DETAIL_VSOP2013_VSOP2013_{0}_HPP
#define HEYOKA_DETAIL_VSOP2013_VSOP2013_{0}_HPP

#include <heyoka/config.hpp>
#include <heyoka/detail/vsop2013/vsop2013_term.hpp>

HEYOKA_BEGIN_NAMESPACE

namespace model::detail
{{

{1}

}} // namespace model::detail

HEYOKA_END_NAMESPACE

#endif

"""

# Template for the cpp file output.
CPP_FILE_TMPLT = r"""#include <heyoka/config.hpp>
#include <heyoka/detail/vsop2013/vsop2013_{0}.hpp>
#include <heyoka/detail/vsop2013/vsop2013_term.hpp>

HEYOKA_BEGIN_NAMESPACE

namespace model::detail
{{

namespace
{{

{1}

}} // namespace

{2}

}} // namespace model::detail

HEYOKA_END_NAMESPACE

"""


def render_cpp(n):
    import fortranformat as ff

    if not isinstance(n, int) or n < 1 or n > 9:
        raise ValueError("n must be an integer in the [1, 9] range")

    # The fortran format strings for the headers
    # and the terms.
    header_rr = ff.FortranRecordReader("(9x,3i3,i7)")
    term_rr = ff.FortranRecordReader(
        "(i5,1x,4i3,1x,5i3,1x,4i4,1x,i6,1x,3i3,2(f20.16,1x,i3))"
    )

    # Load the data file for planet n.
    with open("VSOP2013p{}.dat".format(n), "r") as f:
        txt = f.readlines()

    # Init the return value. This will be a multidimensional
    # jagged array in which the dimensions mean, in order:
    #
    # - the variable index,
    # - the value of the time power alpha,
    # - the term's index.
    #
    # Thus, for instance:
    #
    # ret[0][1][42]
    #
    # means to get the term at index 42
    # for the time power alpha = 1 for the
    # first variable (index 0).
    ret = list([] for i in range(6))

    cur_idx = 0
    while True:
        # Extract the variable index, the time power and the number of terms
        # for the current section from the header.
        _, v_idx, tpow, nterms = header_rr.read(txt[cur_idx])

        # Read the terms.
        tmp = []
        for j in range(nterms):
            # Parse the term.
            rec = term_rr.read(txt[cur_idx + j + 1])
            assert rec[0] == j + 1

            # Transform the term:
            # - drop the first element (it's just
            #   the term index),
            # - compress the last 4 terms into 2
            #   (the last 4 terms contain the mantissa
            #   and exponent separately).
            new_rec = rec[1:18]
            new_rec.append(float("{:.17g}e{}".format(rec[18], rec[19])))
            new_rec.append(float("{:.17g}e{}".format(rec[20], rec[21])))
            assert len(new_rec) == 19

            tmp.append(new_rec)

        # Add them to ret.
        assert len(ret[v_idx - 1]) == tpow
        ret[v_idx - 1].append(tmp)

        # Update cur_idx, exit if we are at the end.
        cur_idx = cur_idx + nterms + 1
        if cur_idx == len(txt):
            break

    # Create the content for the header.
    header_content = ""
    for coord_idx in range(6):
        header_content += "inline constexpr unsigned long vsop2013_{}_{}_sizes[{}] = {{{}}};\n".format(
            n,
            coord_idx + 1,
            len(ret[coord_idx]),
            ", ".join("{}ul".format(len(_)) for _ in ret[coord_idx]),
        )
    header_content += "\n"
    for coord_idx in range(6):
        header_content += (
            "extern const vsop2013_term * const vsop2013_{}_{}_data[{}];\n".format(
                n, coord_idx + 1, len(ret[coord_idx])
            )
        )

    # Create the content for the cpps.
    cpp_content_1 = []
    for coord_idx in range(6):
        cur_cpp_content = ""

        for j in range(len(ret[coord_idx])):
            cur_cpp_content += "const vsop2013_term vsop2013_{}_{}_{}[{}ul] = ".format(
                n, coord_idx + 1, j, len(ret[coord_idx][j])
            )
            cur_cpp_content += "{"

            nrecs = len(ret[coord_idx][j])

            fmt_string = "{{.a1_a9 = {{{}}}, .a15_a17 = {{{}}}, .a10_a13 = {{{}}}, .a14 = {}, .S = {:.17g}, .C = {:.17g}}}"

            for k in range(nrecs):
                rec = ret[coord_idx][j][k]
                cur_cpp_content += fmt_string.format(
                    ",".join(str(_) for _ in rec[:9]),
                    ",".join(str(_) for _ in rec[14:17]),
                    ",".join(str(_) for _ in rec[9:13]),
                    rec[13],
                    rec[17],
                    rec[18],
                )
                if k != nrecs - 1:
                    cur_cpp_content += ", "

            cur_cpp_content += "};\n\n"

        cpp_content_1.append(cur_cpp_content)

    cpp_content_2 = []
    for coord_idx in range(6):
        cur_cpp_content = ""
        cur_cpp_content += (
            "const vsop2013_term * const vsop2013_{}_{}_data[{}] = {{{}}};\n".format(
                n,
                coord_idx + 1,
                len(ret[coord_idx]),
                ", ".join(
                    [
                        "vsop2013_{}_{}_{}".format(n, coord_idx + 1, j)
                        for j in range(len(ret[coord_idx]))
                    ]
                ),
            )
        )
        cpp_content_2.append(cur_cpp_content)

    return HPP_FILE_TMPLT.format(n, header_content), [
        CPP_FILE_TMPLT.format(n, c1, c2) for c1, c2 in zip(cpp_content_1, cpp_content_2)
    ]

# %%
def worker(pl_idx):
    h_file, cpp_files = render_cpp(pl_idx)

    with open("vsop2013_{}.hpp".format(pl_idx), "w") as f:
        f.write(h_file)

    for coord_idx in range(6):
        with open("vsop2013_{}_{}.cpp".format(pl_idx, coord_idx + 1), "w") as f:
            f.write(cpp_files[coord_idx])

from multiprocessing import Pool

with Pool() as p:
    p.map(worker, range(1, 10))
